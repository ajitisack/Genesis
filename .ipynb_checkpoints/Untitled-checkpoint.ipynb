# %%
import pandas as pd
from pathlib import Path

# %%
filename = r'C:/ajit/stockanalysis/Equity.csv'

# %%
Path(filename)

# %%
pd.read_csv(filename)
# Out:
#       Security Code  Issuer Name Security Id  \
# 0            500002          NaN         ABB
# 1            500003          NaN    AEGISLOG
# 2            500008          NaN  AMARAJABAT
# 3            500009          NaN   AMBALALSA
# 4            500010          NaN        HDFC
# ...             ...          ...         ...
# 4201         780007          NaN        PCPL
# 4202         780008          NaN   SUPERNOVA
# 4203         780013          NaN      CITYON
# 4204         780014          NaN    HASJUICE
# 4205         780016          NaN       WEBSL
#
#                               Security Name  Status Group  Face Value  \
# 0                         ABB India Limited  Active    B          2.0
# 1                      AEGIS LOGISTICS LTD.  Active    A          1.0
# 2                 AMARA RAJA BATTERIES LTD.  Active    A          1.0
# 3         AMBALAL SARABHAI ENTERPRISES LTD.  Active    X         10.0
# 4     HOUSING DEVELOPMENT FINANCE CORP.LTD.  Active    A          2.0
# ...                                     ...     ...   ...         ...
# 4201         Premier Chennai Properties Ltd  Active    IP        10.0
# 4202              Supernova Advertising Ltd  Active    IP        10.0
# 4203             Cityon Systems (India) Ltd  Active    IP        10.0
# 4204                      Has Lifestyle Ltd  Active    IP        10.0
# 4205              Web Element Solutions Ltd  Active    IP        10.0
#
#            ISIN No                      Industry Instrument
# 0     INE117A01022    Heavy Electrical Equipment     Equity
# 1     INE208C01025  Oil Marketing & Distribution     Equity
# 2     INE885A01032        Auto Parts & Equipment     Equity
# 3     INE432A01017               Pharmaceuticals     Equity
# 4     INE001A01036              Housing Finance      Equity
# ...            ...                           ...        ...
# 4201  INE245Q01019                                   Equity
# 4202  INE018Q01010                                   Equity
# 4203  INE324P01014                                   Equity
# 4204  INE888Q01016                                   Equity
# 4205  INE562Q01017                                   Equity
#
# [4206 rows x 10 columns]

# %%
import stockdata as sd

# %%
sd.downloadsymbols()
# Out:
# Fetching list of all BSE and NSE Equities...Completed
# Refreshing table [symbols] with 3984 records...Completed
# Creating index on symbols(symbol)...Completed
# Finished [download] in 2.6057 secs
