# %%
import stockdata as sd
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

# %%
def chart(params, column='close'):
    exchange, symbol = params
    df = sd.gethistprice(exchange, symbol)
    df.set_index('date', inplace=True)
    df[column].plot(figsize=(20, 8))
    plt.title(f"{symbol} - Close Price", fontsize=20)
    plt.ylabel('Price', fontsize=14)
    plt.xlabel('Date', fontsize=14)
    plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
    plt.show()

# %%
def chart_index(index_name):
    symbols = sd.getdata(f"select exchange, symbol from indices where name = '{index_name}'")
    [chart(i) for i in zip(symbols.exchange, symbols.symbol)]

# %%
chart_index('Nifty Bank')

# %%
chart_index('Nifty Information Technology')
