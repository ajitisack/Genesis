# %%
import stockdata as sd
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(style="darkgrid")

# %%
df1 = sd.gethistprice('nse', 'AXISBANK')
df2 = sd.gethistprice('nse', 'INDUSINDBK')

# %%
df1.head()
# Out:
#         date    symbol exchange   open     low    high   close    volume  \
# 0 2020-05-22  AXISBANK      NSE  352.1  332.85  359.75  336.95  48358486
# 1 2020-05-21  AXISBANK      NSE  363.0  355.70  369.00  357.20  24794914
# 2 2020-05-20  AXISBANK      NSE  353.0  350.00  366.30  362.50  30720803
# 3 2020-05-19  AXISBANK      NSE  368.8  350.10  372.50  354.50  42889678
# 4 2020-05-18  AXISBANK      NSE  389.0  352.30  389.00  358.80  47864748
#
#    year  month  day  wkday  wknr  qrtr
# 0  2020      5   22      5    21     2
# 1  2020      5   21      4    21     2
# 2  2020      5   20      3    21     2
# 3  2020      5   19      2    21     2
# 4  2020      5   18      1    21     2

# %%
plt.gcf().set_size_inches(25, 8)
sns.lineplot(x='date', y='close', data=df1)
sns.lineplot(x='date', y='close', data=df2)

# %%
tips = sns.load_dataset("tips")

# %%
sns.relplot(x="total_bill", y="tip", hue="smoker",
            col="time", data=tips);
